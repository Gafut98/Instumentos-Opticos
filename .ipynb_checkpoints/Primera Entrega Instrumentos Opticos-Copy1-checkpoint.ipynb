# %% [markdown]
# # Declaracion de variables e importacion de biblioteca

# %%
import numpy as np
import matplotlib.pyplot as plt
import cv2
import matplotlib.image as im
import csv
import pandas as pd

#Unidades
nm=1e-9 #Nanometros
um=1e-6 #micrometros
mm=1e-3 #Milimetros

# %% [markdown]
# # Inicializacion del codigo

# %%
#Definicion para manejo de complejos
def ploteo_complejo(mat,indicador,escala):#funcion de ploteo completo 
    #indicador tipo de grafica
    
    #mat=mat. completa que voy a pltear
    #indicador=I para intensidad, A amplitud, P fase
    #escala=1 para nada , 0 para Logaritmica
    if(indicador=="I"): #intensidad
      mat=np.abs(mat)**2 #modulado cuadro
    
    elif(indicador=="A"): #amplitud
      mat=np.abs(mat)
    
    elif(indicador=="P"):
      mat=np.angle(mat)
    else:
      mat=mat

    if(escala==1):  #escala en caso de si no se ve
        plt.figure()
        plt.imshow(mat)
        plt.show()
    else:
        plt.figure()
        plt.imshow(np.log(mat+0.00001)) #escala logaritmica
        plt.show()
        
    return 0

# %% [markdown]
# # Punto a
# Detectar la presencia de objetos transparentes en distribuciones puras de fase

# %%
#Se debe importar una matrix obtenida de un archivo cvs

# %%
#Lectura de la matrix
df = pd.read_csv("a.csv",delimiter=',',dtype='str')
#Lectura de complejo y conversion de datos
mapping = np.vectorize(lambda t:complex(t.replace('i','j')))
#Mapeo de matrix a complejos de python
data = mapping(df)
type(data[0][0])
# Out:
# numpy.complex128

# %%
#verificacion de datos
#objeto de fase puro iluminado con una onda moncromatica
#Una imagen en vez de ser un registro de intensidad es un valor complejo
#resulta de tener un objeto puro de fase , algo iluminado por una onda plana
#Se toma una foto a lo que habia en ese plano
print(data)
type(data)
# Out:
# [[0.99315867-0.1167727j  0.97940977-0.20188241j 0.95479132-0.29727685j
#   ... 0.99770518+0.067708j   0.99573418+0.09226836j
#   0.9945219 +0.10452846j]
#  [0.98816547-0.15339165j 0.9741386 -0.22595129j 0.95105652-0.30901699j
#   ... 0.9984636 +0.05541147j 0.99679532+0.07999425j
#   0.9945219 +0.10452846j]
#  [0.97940977-0.20188241j 0.96182564-0.27366299j 0.94717736-0.32071024j
#   ... 0.99907048+0.04310654j 0.9984636 +0.05541147j
#   0.99679532+0.07999425j]
#  ...
#  [0.88960401+0.45673264j 0.91102265+0.41235632j 0.94315443+0.3323548j
#   ... 0.99982925+0.0184789j  0.9984636 +0.05541147j
#   0.99573418+0.09226836j]
#  [0.88960401+0.45673264j 0.91102265+0.41235632j 0.94315443+0.3323548j
#   ... 0.99907048+0.04310654j 0.99907048+0.04310654j
#   0.99770518+0.067708j  ]
#  [0.92563766+0.37841105j 0.93898836+0.34394892j 0.95838122+0.28549159j
#   ... 0.9916447 +0.12899922j 0.98620075+0.16555388j
#   0.98182256+0.18980109j]]
# numpy.ndarray

# %%
#Transformada de datos
fft_biol=np.fft.fftn(data)
fft_biol1=np.fft.fftshift(fft_biol)

#Grafico de intensidad

ploteo_complejo(fft_biol1,"A",0) #Amplitud
ploteo_complejo(fft_biol1,"I",0) #Intensidad
ploteo_complejo(fft_biol1,"P",1); #Fase

# %%
#Diseñar una matriz que sera una onda monocromatica con fase 0
fondo=np.ones((719,720))

# %%
fft_fondo=np.fft.fftn(fondo)
fft_fondo1=np.fft.fftshift(fft_fondo)

fft_biol=np.fft.fftn(data)
fft_biol1=np.fft.fftshift(fft_biol)

# %%
#Se requiere sumar las intensidades por lo tanto se suma la trasnformada de la onda con la trasnformada
#de la matriz del biologico

suma=fft_fondo1+fft_biol1

# %%
fft_suma=np.fft.fftn(suma)
fft_suma1=np.fft.fftshift(fft_suma)

plt.title("Resultado final")
imagen_observada=plt.imshow(np.abs(fft_suma1),cmap="gray")
plt.savefig("Imagen_Observada.jpg", bbox_inches='tight')
plt.colorbar()
plt.show()

# %%
#Observacion de manera de A-B
restas=-fft_biol1+fft_fondo1
fft_suma=np.fft.fftn(restas)
fft_suma1=np.fft.fftshift(fft_suma)

fft_suma_log=np.log(fft_suma1)
plt.title("Resultado final")

plt.imshow(np.abs(fft_suma_log),cmap="gray")
plt.colorbar()

plt.show()

# %%
new_imagen2=np.fft.ifftn(suma)

#Final
plt.figure()
plt.title("Resultado final")
plt.imshow(np.abs(new_imagen2),cmap="gray")
plt.show()

# %%
#Analisis con mascaras 


mask6=np.ones(np.shape(data),dtype="uint8") #matriz de 1

coordx=int(np.shape(data)[1]/2)
coordy=int(np.shape(data)[0]/2) 

                         #tamaño del radio y cero
cv2.circle(mask6,((coordx),(coordy)),3,0,-1) #Circulo exterior 0
#cv2.circle(mask6,((coordx),(coordy)),1,1,-1)

plt.figure()
plt.imshow(mask6)
plt.colorbar()
plt.show()

# %%
final_1=np.fft.fftn(mask6*fft_biol1)
plt.figure()
plt.title("Resultado final")
plt.imshow(np.abs(final_1),cmap="gray")
plt.show()

# %%
#Vamos a filtrar la imagen, la imagen original sera data

fft_biol=np.fft.ifftn(data)
fft_biol1=np.fft.fftshift(fft_biol)

#Grafico de intensidad

#ploteo_complejo(fft_biol1,"A",0) #Amplitud
#ploteo_complejo(fft_biol1,"I",0) #Intensidad
#ploteo_complejo(fft_biol1,"P",1); #Fase



plt.figure()
plt.title("Intensidad en TF con mascara")
x=plt.imshow(np.log(abs(fft_biol))**2)
plt.show()

# %% [markdown]
# # B

# %%
#Observacion de la imagen que se va a trabajar
from IPython.display import Image
Image("b.png")

# %%
##Importe de imagen requerida y que se utilizara 

bloque21=cv2.imread("b.png",0) #1 es a color,0 grises

# La trasnformada de Fourier   

fft_img=np.fft.fftn(bloque21)
fft_img1=np.fft.fftshift(fft_img)

#Grafico de intensidad

ploteo_complejo(fft_img1,"I",0)

#Grafico de intensidad con mascara hallada abajo
plt.figure()
plt.title("Intensidad en TF con mascara")
plt.imshow(np.log(abs(fft_img1))*mask2)
plt.show()

# %%
#trasnformada inversa de la original
fft_o1=np.fft.ifftn(bloque21)

ploteo_complejo(fft_o1,"I",0);

# %%
#Ahora ya tengo la imagen con su intensidad , tengo que filtrar en el dominio de fourier, por lo cual se crea una mascaca 
#que elimine los puntos de la frecuencia

# %%
#Saber el tamaño que se esta utilizando
np.shape(cv2.imread("b.png",1))
# Out:
# (768, 768, 3)

# %%
#Resultado final

# %%
mask2=np.ones(np.shape(bloque21),dtype="uint8") #matriz de 1

coordx=int(np.shape(bloque21)[1]/2)
coordy=int(np.shape(bloque21)[0]/2) 

                         #tamaño del radio y cero
cv2.circle(mask2,((coordx),(coordy)),27,0,-1) #Circulo exterior 0
cv2.circle(mask2,((coordx),(coordy)),21,1,-1) #Circulo interior 1- > valor de 0-1

#Observacion de la mascara creada
plt.figure()
plt.imshow(mask2)
plt.colorbar()
plt.show()

# %%
#Observacion de mascara para saber que radio es necesario para eliminar las frecuencias
plt.figure()
plt.title("Intensidad en TF con mascara")
plt.imshow(np.log(abs(fft_img1))*mask2)
plt.show()

# %%
#Filtrado final de eliminacion de ruido

new_imagen=np.fft.ifftn(fft_img1*mask2)

#Final
plt.figure()
plt.title("Resultado final")
bloque21_r=plt.imshow(np.abs(new_imagen),cmap="gray")
plt.savefig("Bloque_21O.jpg", bbox_inches='tight')
plt.show()

#Comparando con la original
ori=cv2.imread("b.png",1)

plt.figure()
plt.title("Original")
plt.imshow(np.abs(ori))
plt.show()

# %% [markdown]
# # Punto C

# %% [markdown]
# Detectar opticamente la presencia (ausencia) de un elemento en una imagen compuesta

# %%
#Observar la imagen a trabajar
from IPython.display import Image
Image("c.jpg")

# %%
#El resultado que necesitamos llegar
from IPython.display import Image
Image("c_clue.jpg")

# %%
#importe imagenes a correlacionar

espacio=cv2.imread("c.jpg",1)
joven=cv2.imread("c_clue.jpg",1)

#Tengo estas dos matrices, debo mapear la pequeña en la grande y verificar que si hubo correlacion

# %%
#Dimension espacio
np.shape(espacio)

# %%
#Dimension joven
np.shape(joven)

# %%
#Se tiene una diferencia espacial grande por lo que voy a convertir en matriz ambas imagenes y convertir en 
#imagen del mismo tamano a "espacio"

r=59/1975
r2=59/3000
dim=(int(1975*r),int(3000*r2))
espacio_size=cv2.resize(espacio,dim)
print(espacio_size.shape)
plt.imshow(espacio_size,cmap="gray")

# %%
#Despues de realizada la conversion, ahora si a convertir en Array las imagenes

arreglo_espacio=np.asarray(espacio_size)
arreglo_joven=np.asarray(joven)

# %%
arreglo_joven[0,0]

# %%
#Convolucion


#Trasnformadas de ambas
fft_espacio=np.fft.fftn(espacio)
fft_espacio1=np.fft.fftshift(fft_espacio)

fft_joven=np.fft.fftn(joven)
fft_joven1=np.fft.fftshift(fft_joven)

# %%
corr1 =np.fft.ifft((arreglo_espacio) * arreglo_joven)
#corr2 = ifft(fft(a_and_zeros) * conj(fft(b_and_zeros)))

plt.figure()
plt.imshow(corr1)
plt.show()

# %%
plt.hist(corr1)

# %%
from matplotlib import pyplot as plt

dataframe = pd.DataFrame(np.random.randint(0,200,size=(200, 3)), columns=list('ABC'))

histogram = dataframe.plot.hist()
print(histogram)
plt.show()

# %%
#Graficar

plt.figure()
#plt.title("Intensidad en TF con mascara")
plt.imshow(np.log(abs(fft_joven1)))
plt.show() 
np.shape(joven)

# %%
plt.figure()
#plt.title("Intensidad en TF con mascara")
plt.imshow(np.log(abs(fft_espacio1)))
plt.show()

# %%
##Primero se procesan las dos imagenes (la completa y la pista), pasandolas a blanco y negro

#Valor que define si se convierte a blanco o negro cada pixel
b=110

c = cv2.imread("c.jpg", cv2.IMREAD_GRAYSCALE) #lectura en escala de grises de la imagen
c_clue=cv2.imread("c_clue.jpg", cv2.IMREAD_GRAYSCALE) #lectura en escala de grises de la pista

#conversión a blanco y negro
(thresh, blackAndWhiteImage) = cv2.threshold(c, b, 255, cv2.THRESH_BINARY) 
(thresh, blackAndWhiteImage2) = cv2.threshold(c_clue, b, 255, cv2.THRESH_BINARY)


img = blackAndWhiteImage
img2 = img.copy()
template = blackAndWhiteImage2
w, h = template.shape[::-1]

# Se elige el método de matching, que corresponde a la correlación
method = eval('cv.TM_CCOEFF')

#Se aplica el método
res = cv.matchTemplate(img,template,method)
min_val, max_val, min_loc, max_loc = cv.minMaxLoc(res)
top_left = max_loc
bottom_right = (top_left[0] + w, top_left[1] + h)

#Se pondrá un rectangulo negro al rededor de la imagenque señale el resultado
cv.rectangle(img,top_left, bottom_right, (0,0,0), 2)

#desplegar resultados
fig, axes = plt.subplots(2, 1, figsize=(20, 50))
ax = axes.ravel()

#tamaño de letra de los títulos
plt.rcParams.update({'font.size': 6}) 

ax[0].set_title('Resultado')
ax[0].imshow(res,cmap = 'gray')
ax[0].set_yticklabels([])#no mostrar ticks
ax[0].set_xticklabels([])#no mostrar ticks


ax[1].set_title('Detectar objecto')
ax[1].imshow(img, cmap='gray')
ax[1].set_yticklabels([])#no mostrar ticks
ax[1].set_xticklabels([])#no mostrar ticks

plt.show()

# %%
img = cv2.imread('c.jpg',0)
 
# crear máscara
mask = np.zeros(img.shape[:2], np.uint8)
mask[10:140, 100:200] = 255
masked_img = cv2.bitwise_and(img,img,mask = mask)
 
# Calcular el histohrama con máscara y sin máscara
# Fijar el tercer argumento como "mask"
hist_full = cv2.calcHist([img],[0],None,[256],[0,256])
hist_mask = cv2.calcHist([img],[0],mask,[256],[0,256])
 
plt.subplot(221), plt.imshow(img, 'gray')
plt.subplot(222), plt.imshow(mask,'gray')
plt.subplot(223), plt.imshow(masked_img, 'gray')
plt.subplot(224), plt.plot(hist_full), plt.plot(hist_mask)
plt.xlim([0,256])
